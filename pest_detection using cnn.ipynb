# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import load_model

# Define image size and directories
img_width, img_height = 150, 150
train_data_dir = "C:\\Users\\mahes\\Desktop\\pest\\train"

# Data augmentation
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical',
    subset='validation')

# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(9, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(train_generator, steps_per_epoch=len(train_generator), epochs=50, validation_data=validation_generator, validation_steps=len(validation_generator))

# Save the model
model.save('pest_detection_model.h5')

# Load the model and predict on user input image
model = load_model('pest_detection_model.h5')

def predict_image(image_path):
    image = load_img(image_path, target_size=(img_width, img_height))
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
    image /= 255.

    prediction = model.predict(image)
    classes = train_generator.class_indices
    class_labels = list(classes.keys())
    
    predicted_class = class_labels[np.argmax(prediction)]
    return predicted_class

# Predict on the input image
input_image_path = "C:\\Users\\mahes\\Desktop\\pest\\test\\mosquito\\jpg_11.jpg"
result = predict_image(input_image_path)
print(f"Detected pest: {result}")
# Out:
# Found 2160 images belonging to 9 classes.
# Found 540 images belonging to 9 classes.
# Epoch 1/50
# 68/68 [==============================] - 21s 298ms/step - loss: 2.1996 - accuracy: 0.1264 - val_loss: 2.1629 - val_accuracy: 0.1833
# Epoch 2/50
# 68/68 [==============================] - 20s 295ms/step - loss: 2.0832 - accuracy: 0.1912 - val_loss: 1.9804 - val_accuracy: 0.3111
# Epoch 3/50
# 68/68 [==============================] - 20s 294ms/step - loss: 1.9812 - accuracy: 0.2417 - val_loss: 1.8859 - val_accuracy: 0.2944
# Epoch 4/50
# 68/68 [==============================] - 20s 293ms/step - loss: 1.8821 - accuracy: 0.2815 - val_loss: 1.8640 - val_accuracy: 0.3500
# Epoch 5/50
# 68/68 [==============================] - 20s 293ms/step - loss: 1.8250 - accuracy: 0.2977 - val_loss: 1.7603 - val_accuracy: 0.3593
# Epoch 6/50
# 68/68 [==============================] - 20s 295ms/step - loss: 1.7720 - accuracy: 0.3171 - val_loss: 1.7930 - val_accuracy: 0.3259
# Epoch 7/50
# 68/68 [==============================] - 20s 294ms/step - loss: 1.6862 - accuracy: 0.3509 - val_loss: 1.8215 - val_accuracy: 0.3148
# Epoch 8/50
# 68/68 [==============================] - 20s 293ms/step - loss: 1.5856 - accuracy: 0.3935 - val_loss: 1.7350 - val_accuracy: 0.3796
# Epoch 9/50
# 68/68 [==============================] - 20s 291ms/step - loss: 1.5219 - accuracy: 0.4125 - val_loss: 1.7410 - val_accuracy: 0.4019
# Epoch 10/50
# 68/68 [==============================] - 20s 293ms/step - loss: 1.4556 - accuracy: 0.4287 - val_loss: 1.7328 - val_accuracy: 0.4130
# Epoch 11/50
# 68/68 [==============================] - 20s 294ms/step - loss: 1.4032 - accuracy: 0.4588 - val_loss: 1.8299 - val_accuracy: 0.3963
# Epoch 12/50
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3159 - accuracy: 0.4968 - val_loss: 1.8812 - val_accuracy: 0.3778
# Epoch 13/50
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2578 - accuracy: 0.4986 - val_loss: 1.8519 - val_accuracy: 0.4259
# Epoch 14/50
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1914 - accuracy: 0.5250 - val_loss: 1.8972 - val_accuracy: 0.4259
# Epoch 15/50
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1430 - accuracy: 0.5495 - val_loss: 1.8092 - val_accuracy: 0.4000
# Epoch 16/50
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1124 - accuracy: 0.5611 - val_loss: 2.0019 - val_accuracy: 0.4352
# Epoch 17/50
# 68/68 [==============================] - 20s 292ms/step - loss: 1.0267 - accuracy: 0.5977 - val_loss: 2.1196 - val_accuracy: 0.4241
# Epoch 18/50
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0068 - accuracy: 0.5995 - val_loss: 1.9739 - val_accuracy: 0.4481
# Epoch 19/50
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9873 - accuracy: 0.6046 - val_loss: 1.9550 - val_accuracy: 0.4722
# Epoch 20/50
# 68/68 [==============================] - 20s 294ms/step - loss: 0.9089 - accuracy: 0.6176 - val_loss: 2.1392 - val_accuracy: 0.4500
# Epoch 21/50
# 68/68 [==============================] - 20s 294ms/step - loss: 0.8939 - accuracy: 0.6394 - val_loss: 1.9500 - val_accuracy: 0.4463
# Epoch 22/50
# 68/68 [==============================] - 20s 295ms/step - loss: 0.8921 - accuracy: 0.6454 - val_loss: 2.1500 - val_accuracy: 0.4426
# Epoch 23/50
# 68/68 [==============================] - 20s 296ms/step - loss: 0.8638 - accuracy: 0.6542 - val_loss: 2.1150 - val_accuracy: 0.4667
# Epoch 24/50
# 68/68 [==============================] - 21s 309ms/step - loss: 0.8035 - accuracy: 0.6745 - val_loss: 2.1414 - val_accuracy: 0.4463
# Epoch 25/50
# 68/68 [==============================] - 21s 311ms/step - loss: 0.7940 - accuracy: 0.6773 - val_loss: 1.9839 - val_accuracy: 0.4407
# Epoch 26/50
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7989 - accuracy: 0.6731 - val_loss: 2.1613 - val_accuracy: 0.4426
# Epoch 27/50
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7828 - accuracy: 0.6731 - val_loss: 2.4549 - val_accuracy: 0.4259
# Epoch 28/50
# 68/68 [==============================] - 21s 305ms/step - loss: 0.7828 - accuracy: 0.6981 - val_loss: 2.3209 - val_accuracy: 0.4759
# Epoch 29/50
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7360 - accuracy: 0.7093 - val_loss: 2.3597 - val_accuracy: 0.4556
# Epoch 30/50
# 68/68 [==============================] - 20s 300ms/step - loss: 0.7675 - accuracy: 0.6954 - val_loss: 2.2407 - val_accuracy: 0.4667
# Epoch 31/50
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6937 - accuracy: 0.7181 - val_loss: 2.2403 - val_accuracy: 0.4444
# Epoch 32/50
# 68/68 [==============================] - 20s 301ms/step - loss: 0.6700 - accuracy: 0.7287 - val_loss: 2.4756 - val_accuracy: 0.4852
# Epoch 33/50
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6484 - accuracy: 0.7343 - val_loss: 2.8021 - val_accuracy: 0.4833
# Epoch 34/50
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7144 - accuracy: 0.7093 - val_loss: 2.2433 - val_accuracy: 0.4630
# Epoch 35/50
# 68/68 [==============================] - 20s 301ms/step - loss: 0.6836 - accuracy: 0.7366 - val_loss: 2.6060 - val_accuracy: 0.4704
# Epoch 36/50
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6569 - accuracy: 0.7440 - val_loss: 2.6007 - val_accuracy: 0.4907
# Epoch 37/50
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6222 - accuracy: 0.7514 - val_loss: 2.4895 - val_accuracy: 0.4537
# Epoch 38/50
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6272 - accuracy: 0.7375 - val_loss: 2.5679 - val_accuracy: 0.4981
# Epoch 39/50
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6226 - accuracy: 0.7398 - val_loss: 2.8888 - val_accuracy: 0.4796
# Epoch 40/50
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6179 - accuracy: 0.7449 - val_loss: 2.3612 - val_accuracy: 0.4704
# Epoch 41/50
# 68/68 [==============================] - 20s 292ms/step - loss: 0.5346 - accuracy: 0.7750 - val_loss: 2.5615 - val_accuracy: 0.4796
# Epoch 42/50
# 68/68 [==============================] - 20s 292ms/step - loss: 0.5333 - accuracy: 0.7796 - val_loss: 2.7120 - val_accuracy: 0.4944
# Epoch 43/50
# 68/68 [==============================] - 20s 294ms/step - loss: 0.5543 - accuracy: 0.7662 - val_loss: 3.0671 - val_accuracy: 0.4667
# Epoch 44/50
# 68/68 [==============================] - 20s 294ms/step - loss: 0.5237 - accuracy: 0.7852 - val_loss: 3.0907 - val_accuracy: 0.4315
# Epoch 45/50
# 68/68 [==============================] - 20s 293ms/step - loss: 0.5436 - accuracy: 0.7722 - val_loss: 3.0298 - val_accuracy: 0.4815
# Epoch 46/50
# 68/68 [==============================] - 20s 292ms/step - loss: 0.5591 - accuracy: 0.7667 - val_loss: 2.7479 - val_accuracy: 0.4981
# Epoch 47/50
# 68/68 [==============================] - 20s 292ms/step - loss: 0.5341 - accuracy: 0.7819 - val_loss: 2.9071 - val_accuracy: 0.4870
# Epoch 48/50
# 68/68 [==============================] - 20s 294ms/step - loss: 0.5004 - accuracy: 0.7792 - val_loss: 2.8925 - val_accuracy: 0.4778
# Epoch 49/50
# 68/68 [==============================] - 20s 293ms/step - loss: 0.4917 - accuracy: 0.7963 - val_loss: 3.2379 - val_accuracy: 0.5037
# Epoch 50/50
# 68/68 [==============================] - 20s 297ms/step - loss: 0.4925 - accuracy: 0.7958 - val_loss: 3.1346 - val_accuracy: 0.4907
# C:\Users\mahes\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 121ms/step
# Detected pest: mosquito
